# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.
import sys
import pandas as pd
import numpy as np
import random
import array as arr
from collections import deque
import torch
from agents.agent import TD3
from tasks.taskfly import Task

random_seed = 1234
torch.manual_seed(random_seed)
np.random.seed(random_seed)

env_name = 'Quadcopter'
directory = "./preTrained/" 
filename = "TD3_{}_{}".format(env_name, random_seed)

print_every = 1
#num_episodes = 150
num_episodes = 200

init_pose = np.array([0., 0., 1., 0., 0., 0.])
target_pos = np.array([5., 5., 10.])
task = Task(init_pose=init_pose, target_pos=target_pos)

agent = TD3(task) 

best_score = 0
scores = []
episode_rewards = []
ep_rewards_deque = deque(maxlen=100)

for i_episode in range(1, num_episodes+1):
        state = agent.reset_episode()
        
        steps = 0
        score = 0.
        
        while True:
            action = agent.act(state) 

            next_state, reward, done = agent.task.step(action)
            agent.step(action, reward, next_state, done)

            state = next_state
            score += reward
            steps += 1
            if done:
                break

        scores.append(score)
        
        if score > best_score:
            best_score = score 

        if i_episode % print_every == 0:
            text = "Episodes: {:4d}, ".format(len(scores))
            text += "Last Score: {:.1f}, ".format(score)
            text += "Average Score: {:.1f}, ".format(np.mean(scores[-25:]))
            text += "Best Score: {:.1f}".format(best_score)
            print(text)       
            
agent.save(directory, filename)
# Out:
# Episodes:    1, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:    2, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:    3, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:    4, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:    5, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:    6, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:    7, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:    8, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:    9, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:   10, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:   11, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:   12, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# Episodes:   13, Last Score: 174.0, Average Score: 174.0, Best Score: 174.0
# TIME
# TIME
# Episodes:   14, Last Score: 1824.2, Average Score: 291.9, Best Score: 1824.2
# Episodes:   15, Last Score: 195.8, Average Score: 285.5, Best Score: 1824.2
# Episodes:   16, Last Score: 391.4, Average Score: 292.1, Best Score: 1824.2
# Episodes:   17, Last Score: 995.5, Average Score: 333.5, Best Score: 1824.2
# Episodes:   18, Last Score: 1118.8, Average Score: 377.1, Best Score: 1824.2
# Episodes:   19, Last Score: 827.7, Average Score: 400.8, Best Score: 1824.2
# Episodes:   20, Last Score: 1012.3, Average Score: 431.4, Best Score: 1824.2
# Episodes:   21, Last Score: 174.1, Average Score: 419.2, Best Score: 1824.2
# Episodes:   22, Last Score: 174.0, Average Score: 408.0, Best Score: 1824.2
# Episodes:   23, Last Score: 174.1, Average Score: 397.8, Best Score: 1824.2
# Episodes:   24, Last Score: 195.9, Average Score: 389.4, Best Score: 1824.2
# Episodes:   25, Last Score: 152.3, Average Score: 379.9, Best Score: 1824.2
# Episodes:   26, Last Score: 152.3, Average Score: 379.1, Best Score: 1824.2
# Episodes:   27, Last Score: 152.3, Average Score: 378.2, Best Score: 1824.2
# Episodes:   28, Last Score: 152.3, Average Score: 377.3, Best Score: 1824.2
# Episodes:   29, Last Score: 174.1, Average Score: 377.3, Best Score: 1824.2
# Episodes:   30, Last Score: 217.7, Average Score: 379.1, Best Score: 1824.2
# Episodes:   31, Last Score: 631.2, Average Score: 397.4, Best Score: 1824.2
# Episodes:   32, Last Score: 195.8, Average Score: 398.2, Best Score: 1824.2
# Episodes:   33, Last Score: 195.8, Average Score: 399.1, Best Score: 1824.2
# Episodes:   34, Last Score: 348.1, Average Score: 406.1, Best Score: 1824.2
# Episodes:   35, Last Score: 348.2, Average Score: 413.0, Best Score: 1824.2
# Episodes:   36, Last Score: 152.3, Average Score: 412.2, Best Score: 1824.2
# Episodes:   37, Last Score: 217.6, Average Score: 413.9, Best Score: 1824.2
# Episodes:   38, Last Score: 326.4, Average Score: 420.0, Best Score: 1824.2
# Episodes:   39, Last Score: 152.3, Average Score: 353.1, Best Score: 1824.2
# Episodes:   40, Last Score: 174.0, Average Score: 352.3, Best Score: 1824.2
# Episodes:   41, Last Score: 631.3, Average Score: 361.9, Best Score: 1824.2
# Episodes:   42, Last Score: 174.0, Average Score: 329.0, Best Score: 1824.2
# Episodes:   43, Last Score: 239.2, Average Score: 293.8, Best Score: 1824.2
# Episodes:   44, Last Score: 239.2, Average Score: 270.3, Best Score: 1824.2
# Episodes:   45, Last Score: 239.3, Average Score: 239.4, Best Score: 1824.2
# Episodes:   46, Last Score: 326.3, Average Score: 245.4, Best Score: 1824.2
# Episodes:   47, Last Score: 174.0, Average Score: 245.4, Best Score: 1824.2
# Episodes:   48, Last Score: 152.3, Average Score: 244.6, Best Score: 1824.2
# Episodes:   49, Last Score: 152.3, Average Score: 242.8, Best Score: 1824.2
# Episodes:   50, Last Score: 391.6, Average Score: 252.4, Best Score: 1824.2
# Episodes:   51, Last Score: 174.0, Average Score: 253.3, Best Score: 1824.2
# Episodes:   52, Last Score: 304.6, Average Score: 259.4, Best Score: 1824.2
# Episodes:   53, Last Score: 152.3, Average Score: 259.4, Best Score: 1824.2
# Episodes:   54, Last Score: 239.2, Average Score: 262.0, Best Score: 1824.2
# Episodes:   55, Last Score: 174.0, Average Score: 260.2, Best Score: 1824.2
# Episodes:   56, Last Score: 195.8, Average Score: 242.8, Best Score: 1824.2
# Episodes:   57, Last Score: 586.8, Average Score: 258.4, Best Score: 1824.2
# Episodes:   58, Last Score: 108.8, Average Score: 255.0, Best Score: 1824.2
# Episodes:   59, Last Score: 108.8, Average Score: 245.4, Best Score: 1824.2
# Episodes:   60, Last Score: 130.6, Average Score: 236.7, Best Score: 1824.2
# Episodes:   61, Last Score: 631.5, Average Score: 255.8, Best Score: 1824.2
# Episodes:   62, Last Score: 1277.3, Average Score: 298.2, Best Score: 1824.2
# Episodes:   63, Last Score: 499.6, Average Score: 305.2, Best Score: 1824.2
# Episodes:   64, Last Score: 130.5, Average Score: 304.3, Best Score: 1824.2
# Episodes:   65, Last Score: 130.5, Average Score: 302.6, Best Score: 1824.2
# Episodes:   66, Last Score: 195.7, Average Score: 285.1, Best Score: 1824.2
# Episodes:   67, Last Score: 108.8, Average Score: 282.5, Best Score: 1824.2
# Episodes:   68, Last Score: 391.6, Average Score: 288.6, Best Score: 1824.2
# Episodes:   69, Last Score: 304.6, Average Score: 291.2, Best Score: 1824.2
# Episodes:   70, Last Score: 282.8, Average Score: 293.0, Best Score: 1824.2
# Episodes:   71, Last Score: 282.8, Average Score: 291.2, Best Score: 1824.2
# Episodes:   72, Last Score: 304.6, Average Score: 296.5, Best Score: 1824.2
# Episodes:   73, Last Score: 282.8, Average Score: 301.7, Best Score: 1824.2
# Episodes:   74, Last Score: 261.1, Average Score: 306.0, Best Score: 1824.2
# Episodes:   75, Last Score: 326.3, Average Score: 303.4, Best Score: 1824.2
# Episodes:   76, Last Score: 261.1, Average Score: 306.9, Best Score: 1824.2
# Episodes:   77, Last Score: 304.6, Average Score: 306.9, Best Score: 1824.2
# Episodes:   78, Last Score: 304.6, Average Score: 313.0, Best Score: 1824.2
# Episodes:   79, Last Score: 304.6, Average Score: 315.6, Best Score: 1824.2
# Episodes:   80, Last Score: 282.8, Average Score: 320.0, Best Score: 1824.2
# Episodes:   81, Last Score: 391.5, Average Score: 327.8, Best Score: 1824.2
# Episodes:   82, Last Score: 282.8, Average Score: 315.6, Best Score: 1824.2
# Episodes:   83, Last Score: 304.6, Average Score: 323.5, Best Score: 1824.2
# Episodes:   84, Last Score: 282.8, Average Score: 330.4, Best Score: 1824.2
# Episodes:   85, Last Score: 282.8, Average Score: 336.5, Best Score: 1824.2
# Episodes:   86, Last Score: 282.8, Average Score: 322.6, Best Score: 1824.2
# Episodes:   87, Last Score: 282.8, Average Score: 282.8, Best Score: 1824.2
# Episodes:   88, Last Score: 369.8, Average Score: 277.6, Best Score: 1824.2
# Episodes:   89, Last Score: 304.5, Average Score: 284.6, Best Score: 1824.2
# Episodes:   90, Last Score: 282.8, Average Score: 290.6, Best Score: 1824.2
# Episodes:   91, Last Score: 261.0, Average Score: 293.3, Best Score: 1824.2
# Episodes:   92, Last Score: 282.8, Average Score: 300.2, Best Score: 1824.2
# Episodes:   93, Last Score: 282.8, Average Score: 295.9, Best Score: 1824.2
# Episodes:   94, Last Score: 282.8, Average Score: 295.0, Best Score: 1824.2
# Episodes:   95, Last Score: 282.8, Average Score: 295.0, Best Score: 1824.2
# Episodes:   96, Last Score: 282.8, Average Score: 295.0, Best Score: 1824.2
# Episodes:   97, Last Score: 282.8, Average Score: 294.1, Best Score: 1824.2
# Episodes:   98, Last Score: 282.8, Average Score: 294.1, Best Score: 1824.2
# Episodes:   99, Last Score: 413.4, Average Score: 300.2, Best Score: 1824.2
# Episodes:  100, Last Score: 282.8, Average Score: 298.5, Best Score: 1824.2
# Episodes:  101, Last Score: 217.5, Average Score: 296.7, Best Score: 1824.2
# Episodes:  102, Last Score: 348.0, Average Score: 298.5, Best Score: 1824.2
# Episodes:  103, Last Score: 304.6, Average Score: 298.5, Best Score: 1824.2
# Episodes:  104, Last Score: 369.7, Average Score: 301.1, Best Score: 1824.2
# Episodes:  105, Last Score: 261.0, Average Score: 300.2, Best Score: 1824.2
# Episodes:  106, Last Score: 152.3, Average Score: 290.6, Best Score: 1824.2
# Episodes:  107, Last Score: 369.7, Average Score: 294.1, Best Score: 1824.2
# Episodes:  108, Last Score: 326.6, Average Score: 295.0, Best Score: 1824.2
# Episodes:  109, Last Score: 391.7, Average Score: 299.3, Best Score: 1824.2
# Episodes:  110, Last Score: 108.8, Average Score: 292.4, Best Score: 1824.2
# Episodes:  111, Last Score: 108.8, Average Score: 285.4, Best Score: 1824.2
# Episodes:  112, Last Score: 108.8, Average Score: 278.5, Best Score: 1824.2
# Episodes:  113, Last Score: 108.8, Average Score: 268.0, Best Score: 1824.2
# Episodes:  114, Last Score: 108.8, Average Score: 260.2, Best Score: 1824.2
# Episodes:  115, Last Score: 108.8, Average Score: 253.2, Best Score: 1824.2
# Episodes:  116, Last Score: 108.8, Average Score: 247.1, Best Score: 1824.2
# Episodes:  117, Last Score: 130.5, Average Score: 241.0, Best Score: 1824.2
# Episodes:  118, Last Score: 130.5, Average Score: 234.9, Best Score: 1824.2
# Episodes:  119, Last Score: 130.5, Average Score: 228.9, Best Score: 1824.2
# Episodes:  120, Last Score: 130.5, Average Score: 222.8, Best Score: 1824.2
# Episodes:  121, Last Score: 152.2, Average Score: 217.5, Best Score: 1824.2
# Episodes:  122, Last Score: 152.3, Average Score: 212.3, Best Score: 1824.2
# Episodes:  123, Last Score: 152.3, Average Score: 207.1, Best Score: 1824.2
# Episodes:  124, Last Score: 174.0, Average Score: 197.5, Best Score: 1824.2
# Episodes:  125, Last Score: 174.0, Average Score: 193.2, Best Score: 1824.2
# Episodes:  126, Last Score: 195.7, Average Score: 192.3, Best Score: 1824.2
# Episodes:  127, Last Score: 195.7, Average Score: 186.2, Best Score: 1824.2
# Episodes:  128, Last Score: 217.5, Average Score: 182.7, Best Score: 1824.2
# Episodes:  129, Last Score: 239.2, Average Score: 177.5, Best Score: 1824.2
# Episodes:  130, Last Score: 260.9, Average Score: 177.5, Best Score: 1824.2
# Episodes:  131, Last Score: 304.4, Average Score: 183.6, Best Score: 1824.2
# Episodes:  132, Last Score: 369.5, Average Score: 183.6, Best Score: 1824.2
# Episodes:  133, Last Score: 456.2, Average Score: 188.8, Best Score: 1824.2
# Episodes:  134, Last Score: 564.6, Average Score: 195.7, Best Score: 1824.2
# Episodes:  135, Last Score: 716.1, Average Score: 220.0, Best Score: 1824.2
# Episodes:  136, Last Score: 931.3, Average Score: 252.9, Best Score: 1824.2
# Episodes:  137, Last Score: 1208.9, Average Score: 296.9, Best Score: 1824.2
# Episodes:  138, Last Score: 1567.4, Average Score: 355.2, Best Score: 1824.2
# TIME
# TIME
# Episodes:  139, Last Score: 1795.0, Average Score: 422.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  140, Last Score: 1793.9, Average Score: 490.1, Best Score: 1824.2
# TIME
# TIME
# Episodes:  141, Last Score: 1793.7, Average Score: 557.5, Best Score: 1824.2
# TIME
# TIME
# Episodes:  142, Last Score: 1794.1, Average Score: 624.0, Best Score: 1824.2
# TIME
# TIME
# Episodes:  143, Last Score: 1794.6, Average Score: 690.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  144, Last Score: 1795.4, Average Score: 757.2, Best Score: 1824.2
# TIME
# TIME
# Episodes:  145, Last Score: 1796.1, Average Score: 823.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  146, Last Score: 1796.7, Average Score: 889.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  147, Last Score: 1797.2, Average Score: 955.4, Best Score: 1824.2
# TIME
# TIME
# Episodes:  148, Last Score: 1797.6, Average Score: 1021.2, Best Score: 1824.2
# TIME
# TIME
# Episodes:  149, Last Score: 1798.0, Average Score: 1086.1, Best Score: 1824.2
# TIME
# TIME
# Episodes:  150, Last Score: 1798.2, Average Score: 1151.1, Best Score: 1824.2
# TIME
# TIME
# Episodes:  151, Last Score: 1798.5, Average Score: 1215.2, Best Score: 1824.2
# TIME
# TIME
# Episodes:  152, Last Score: 1798.6, Average Score: 1279.3, Best Score: 1824.2
# TIME
# TIME
# Episodes:  153, Last Score: 1798.8, Average Score: 1342.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  154, Last Score: 1798.9, Average Score: 1405.0, Best Score: 1824.2
# TIME
# TIME
# Episodes:  155, Last Score: 1799.0, Average Score: 1466.5, Best Score: 1824.2
# TIME
# TIME
# Episodes:  156, Last Score: 1799.1, Average Score: 1526.3, Best Score: 1824.2
# TIME
# TIME
# Episodes:  157, Last Score: 1799.2, Average Score: 1583.5, Best Score: 1824.2
# TIME
# TIME
# Episodes:  158, Last Score: 1799.3, Average Score: 1637.2, Best Score: 1824.2
# TIME
# TIME
# Episodes:  159, Last Score: 1799.4, Average Score: 1686.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  160, Last Score: 1799.4, Average Score: 1729.9, Best Score: 1824.2
# TIME
# TIME
# Episodes:  161, Last Score: 1799.4, Average Score: 1764.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  162, Last Score: 1799.5, Average Score: 1788.3, Best Score: 1824.2
# TIME
# TIME
# Episodes:  163, Last Score: 1799.5, Average Score: 1797.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  164, Last Score: 1799.5, Average Score: 1797.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  165, Last Score: 1799.6, Average Score: 1798.0, Best Score: 1824.2
# TIME
# TIME
# Episodes:  166, Last Score: 1799.6, Average Score: 1798.2, Best Score: 1824.2
# TIME
# TIME
# Episodes:  167, Last Score: 1799.6, Average Score: 1798.4, Best Score: 1824.2
# TIME
# TIME
# Episodes:  168, Last Score: 1799.6, Average Score: 1798.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  169, Last Score: 1799.7, Average Score: 1798.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  170, Last Score: 1799.7, Average Score: 1798.9, Best Score: 1824.2
# TIME
# TIME
# Episodes:  171, Last Score: 1799.7, Average Score: 1799.1, Best Score: 1824.2
# TIME
# TIME
# Episodes:  172, Last Score: 1799.7, Average Score: 1799.2, Best Score: 1824.2
# TIME
# TIME
# Episodes:  173, Last Score: 1799.7, Average Score: 1799.3, Best Score: 1824.2
# TIME
# TIME
# Episodes:  174, Last Score: 1799.7, Average Score: 1799.3, Best Score: 1824.2
# TIME
# TIME
# Episodes:  175, Last Score: 1799.7, Average Score: 1799.4, Best Score: 1824.2
# TIME
# TIME
# Episodes:  176, Last Score: 1799.7, Average Score: 1799.4, Best Score: 1824.2
# TIME
# TIME
# Episodes:  177, Last Score: 1799.7, Average Score: 1799.5, Best Score: 1824.2
# TIME
# TIME
# Episodes:  178, Last Score: 1799.8, Average Score: 1799.5, Best Score: 1824.2
# TIME
# TIME
# Episodes:  179, Last Score: 1799.8, Average Score: 1799.5, Best Score: 1824.2
# TIME
# TIME
# Episodes:  180, Last Score: 1799.8, Average Score: 1799.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  181, Last Score: 1799.8, Average Score: 1799.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  182, Last Score: 1799.8, Average Score: 1799.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  183, Last Score: 1799.8, Average Score: 1799.6, Best Score: 1824.2
# TIME
# TIME
# Episodes:  184, Last Score: 1799.8, Average Score: 1799.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  185, Last Score: 1799.8, Average Score: 1799.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  186, Last Score: 1799.8, Average Score: 1799.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  187, Last Score: 1799.8, Average Score: 1799.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  188, Last Score: 1799.8, Average Score: 1799.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  189, Last Score: 1799.8, Average Score: 1799.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  190, Last Score: 1799.8, Average Score: 1799.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  191, Last Score: 1799.8, Average Score: 1799.7, Best Score: 1824.2
# TIME
# TIME
# Episodes:  192, Last Score: 1799.8, Average Score: 1799.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  193, Last Score: 1799.8, Average Score: 1799.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  194, Last Score: 1799.8, Average Score: 1799.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  195, Last Score: 1799.8, Average Score: 1799.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  196, Last Score: 1799.8, Average Score: 1799.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  197, Last Score: 1799.8, Average Score: 1799.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  198, Last Score: 1799.9, Average Score: 1799.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  199, Last Score: 1799.9, Average Score: 1799.8, Best Score: 1824.2
# TIME
# TIME
# Episodes:  200, Last Score: 1799.9, Average Score: 1799.8, Best Score: 1824.2

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(15,5))
plt.plot(scores, color='red', label='Reward')
plt.ylabel('Reward')
plt.legend(loc=2)
plt.grid(True)

plt.xlabel("Episode #")
plt.xlim(0, len(scores))
plt.show()

# %%
task = Task(init_pose=init_pose, runtime=5000, target_pos=target_pos)

agent = TD3(task)    
agent.load_actor(directory, filename)    
        
route = []    

state = agent.reset_episode()
while True:        
    action = agent.act(state)         
    next_state, reward, done = agent.task.step(action)
    route.append((agent.task.sim.pose[0], agent.task.sim.pose[1], agent.task.sim.pose[2]))
    agent.step(action, reward, next_state, done)
    if done:
        break

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

s = []
[s.append((init_pose[0], init_pose[1], init_pose[2])) for _ in range(len(route))]

t = []
[t.append((target_pos[0], target_pos[1], target_pos[2])) for _ in range(len(route))]

data = (s, route, t)
colors = ("green", "blue", "red")
groups = ("Start", "Route", "Target") 

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, axisbg="1.0")
ax = fig.gca(projection='3d')
 
for data, color, group in zip(data, colors, groups):    
    x = [value[0] for value in data]
    y = [value[1] for value in data]
    z = [value[2] for value in data]
    ax.scatter(x, y, z, alpha=0.8, c=color, edgecolors='none', s=50, label=group)
 
plt.title('Flying Route')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
# For this task I used a [TD3 algorithm](https://arxiv.org/pdf/1802.09477.pdf).
# I also tried the DDPG, but decided to use the TD3 because of the better performance.
#
# __Critic:__
# Input Layer: (state dim + action dim, 400) + ReLU
# Hidden Layer: (action dim + 400, 300) + ReLU
# Output Layer: (300, 1)
#
# __Actor:__
# Input Layer: (state dim, 400) + ReLU
# Hidden Layer: (400, 300) + ReLU
# Output Layer: (300, 1) + tanh
#
# __Hyperparameters:__
# gamma = 0.99
# tau = 1e-3
# policy_noise = 0.1
# noise_clip = 0.5
# policy_delay = 2
# lr_actor = 1e-3
# lr_critic = 1e-3

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
